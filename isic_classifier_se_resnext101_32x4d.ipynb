# %% [markdown]
# # ISIC Skin Lesion Analysis Towards Melanoma Detection
# Skin cancer is the most common cancer globally, with melanoma being the most deadly form. Dermoscopy is a skin imaging modality that has demonstrated improvement for diagnosis of skin cancer compared to unaided visual inspection. However, clinicians should receive adequate training for those improvements to be realized. In order to make expertise more widely available, the International Skin Imaging Collaboration (ISIC) has developed the ISIC Archive, an international repository of dermoscopic images, for both the purposes of clinical training, and for supporting technical research toward automated algorithmic analysis by hosting the ISIC Challenges. https://challenge2019.isic-archive.com/
#
# ISIC Live Leaderboards (2019: Lesion Diagnosis) https://challenge2019.isic-archive.com/live-leaderboard.html
#
# 0.572 Overall Score
#
# 0.861 Validation Score

# %%
model_name = 'se_resnext101_32x4d'

# %%
approach_name = 'preproc_ext_data_thres'

# %%
use_external_data = True
use_weighted_loss = False

# %%
filename = "{}_{}".format(model_name, approach_name)
filename
# Out:
# 'se_resnext101_32x4d_preproc_ext_data_thres'

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

import pandas as pd
import seaborn as sns

# %%
import pretrainedmodels

# %% [markdown]
# ![ballchart_cnn_top1.png](attachment:ballchart_cnn_top1.png)
# Bianco, S., Cadene, R., Celona, L., and Napoletano, P., Benchmark Analysis of Representative Deep Neural Network Architectures. IEEE Access, 6:64270–64277, 2018, via MLPerf https://arxiv.org/abs/1810.00736

# %% [markdown]
# Available pretrained models: https://github.com/Cadene/pretrained-models.pytorch

# %%
print(pretrainedmodels.model_names)
# Out:
# ['fbresnet152', 'bninception', 'resnext101_32x4d', 'resnext101_64x4d', 'inceptionv4', 'inceptionresnetv2', 'alexnet', 'densenet121', 'densenet169', 'densenet201', 'densenet161', 'resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152', 'inceptionv3', 'squeezenet1_0', 'squeezenet1_1', 'vgg11', 'vgg11_bn', 'vgg13', 'vgg13_bn', 'vgg16', 'vgg16_bn', 'vgg19_bn', 'vgg19', 'nasnetamobile', 'nasnetalarge', 'dpn68', 'dpn68b', 'dpn92', 'dpn98', 'dpn131', 'dpn107', 'xception', 'senet154', 'se_resnet50', 'se_resnet101', 'se_resnet152', 'se_resnext50_32x4d', 'se_resnext101_32x4d', 'cafferesnet101', 'pnasnet5large', 'polynet']

# %% [markdown]
# ## Batch size

# %% [markdown]
# We have to adjust the batch size to fit within our memory constraints. All input sizes 299x299, except when in parenthesis.

# %% [markdown]
# |   | inceptionresnetv2 16 | se_resnext101_32x4d 8 | se_resnext101_32x4d 16  | polynet 8 | polynet 8 (331) |
# |---|---|---|---|---|---|
# | transfer learning  | 5214MiB | 4306MiB | 7276MiB  | 5854MiB  | 7136MiB |
# | model finetuning | 6140MiB | 4988MiB | 7865MiB | 7042MiB  | x |

# %%
batch_size = 16

# %% [markdown]
# ## ISIC Dataset

# %% [markdown]
# ISIC 2019 data is provided courtesy of the following sources:
# BCN_20000 Dataset: (c) Department of Dermatology, Hospital Clínic de Barcelona
# HAM10000 Dataset: (c) by ViDIR Group, Department of Dermatology, Medical University of Vienna; https://doi.org/10.1038/sdata.2018.161
# MSK Dataset: (c) Anonymous; https://arxiv.org/abs/1710.05006 ; https://arxiv.org/abs/1902.03368
#
# 25,331 images are available for training across 8 different categories:
#
# 1. Melanoma
# 2. Melanocytic nevus
# 3. Basal cell carcinoma
# 4. Actinic keratosis
# 5. Benign keratosis (solar lentigo / seborrheic keratosis / lichen planus-like keratosis)
# 6. Dermatofibroma
# 7. Vascular lesion
# 8. Squamous cell carcinoma
# 9. None of the others

# %% [markdown]
# Abbreviations used in the dataset
# * MEL: Melanoma — a malignant neoplasm derived from melanocytes
# * NV: Melanocytic nevi — benign neoplasms of melanocytes
# * BCC: Basal cell carcinoma — a common variant of epithelial skin cancer that rarely metastasizes but grows destructively if untreated (bccs do not necessarily produce pigmented lesions)
# * AK: Actinic Keratoses and intraepithelial Carcinoma — common non-invasive, variants of squamous cell carcinoma that can be treated locally without surgery
# * BKL: Benign keratosis — a generic class that includes seborrheic keratoses, solar lentigo and lichen-planus like keratoses
# * DF: Dermatofibroma — a benign skin lesion regarded as either a benign proliferation or an inflammatory reaction to minimal trauma
# * VASC: Vascular skin lesions ranging from cherry angiomas to angiokeratomas and pyogenic granulomas
# * SCC: Squamous cell carcinoma — a common form of skin cancer that develops in the squamous cells that make up the middle and outer layers of the skin
# * UNK: None of the others

# %% [markdown]
# ### Preprocessing
# Trim black borders occuring in several images in the ISIC training and test datasets. We use a very small fuzz factor to remove contigous black borders while retaining important parts of the image. Execute only once. This will take some time. Moved preprocessed images to directory isic_preproc.

# %% [markdown]
# <pre>
# cd ISIC_2019_Training_Input
# mogrify -fuzz 5% -bordercolor black -trim +repage -shave 7x7 -format jpg *.jpg
# cd ../ISIC_2019_Test_Input
# mogrify -fuzz 5% -bordercolor black -trim +repage -shave 7x7 -format jpg *.jpg
# </pre>

# %% [markdown]
# ### Training data

# %%
isic_path = 'isic_preproc/ISIC_2019_Training_Input'

# %%
def get_isic_df():
    df = pd.read_csv('ISIC_2019_Training_GroundTruth.csv')
    path_img = 'ISIC_2019_Training_Input'
    
    for label in df.columns[1:]:
        df.loc[df[label] == 1.0, 'label'] = label
        
    df.rename(columns={'image': 'name'}, inplace=True)
    df['name'] = df['name'].apply(lambda x: "{}/{}.jpg".format(isic_path,x))
    df = df[['name', 'label']]
    return df

# %%
ax = sns.countplot(x="label", data=get_isic_df(), order=['NV', 'MEL', 'BCC', 'BKL', 'AK', 'SCC', 'VASC', 'DF','UNK'])

# %% [markdown]
# ### Test data

# %%
isic_test_path = 'isic_preproc/ISIC_2019_Test_Input'

# %%
def get_isic_test_df():
    df = pd.read_csv('ISIC_2019_Test_Metadata.csv', usecols=['image'])
    path_test_img = 'ISIC_2019_Test_Input'
    df.rename(columns={'image': 'name'}, inplace=True)
    return df

# %%
get_isic_test_df()
# Out:
#               name
# 0     ISIC_0034321
# 1     ISIC_0034322
# 2     ISIC_0034323
# 3     ISIC_0034324
# 4     ISIC_0034325
# ...            ...
# 8233  ISIC_0073236
# 8234  ISIC_0073243
# 8235  ISIC_0073250
# 8236  ISIC_0073252
# 8237  ISIC_0073253
#
# [8238 rows x 1 columns]

# %% [markdown]
# ## SD-198 Dataset
# Sun, X., Yang, J., Sun, M. and Wang, K., 2016, October. A benchmark for automatic visual classification of clinical skin disease images. In European Conference on Computer Vision (pp. 206-222). Springer, Cham.
#
# The dataset contains 6,584 images from 198 classes, varying according to scale, color, shape and structure.

# %% [markdown]
# There are some artifacts in the dataset, like sd-198/images/Steroid_Use_abusemisuse_Dermatitis/2015qiangpzb.exe, so we only look for files with the .jpg extension. The database contains macroscopic images, so we are only using it to train for the unknown class.

# %%
sd198_path = 'sd-198/'

# %%
sd198_isic_classes = {'Actinic_solar_Damage(Actinic_Keratosis)' : 'AK',
                       'Basal_Cell_Carcinoma' : 'BCC',
                       'Dermatofibroma' : 'DF',
                       "Becker's_Nevus" : 'NV',
                       'Blue_Nevus' : 'NV',
                       'Congenital_Nevus' : 'NV',
                       'Benign_Keratosis' : 'BKL', 
                       'Seborrheic_Keratosis' : 'BKL', 
                       'Solar_Lentigo' : 'BKL', 
                       'Lichen_Planus' : 'BKL',
                       'Malignant_Melanoma' : 'MEL', 
                       'Metastatic_Carcinoma' : 'MEL',
                       'Lentigo_Maligna_Melanoma' : 'MEL'}

# %%
def get_sd198_df():
    sd198_classes = !ls {sd198_path}/images
    sd198_df = pd.DataFrame()
    for c in sd198_classes:
        images = !find "{sd198_path}images/{c}" -type f -name "*.jpg"
        df = pd.DataFrame()
        df['name'] = images
        
        if c not in sd198_isic_classes.keys():
            df['label'] = 'UNK'
            sd198_df = pd.concat([sd198_df, df])
        #else:
        #    df['label'] = sd198_isic_classes[c]   
        
    return sd198_df

# %%
get_sd198_df()
# Out:
#                                                  name label
# 0   sd-198/images/Acne_Keloidalis_Nuchae/010069HB.jpg   UNK
# 1   sd-198/images/Acne_Keloidalis_Nuchae/042338HB.jpg   UNK
# 2   sd-198/images/Acne_Keloidalis_Nuchae/010018HB.jpg   UNK
# 3   sd-198/images/Acne_Keloidalis_Nuchae/009931HB.jpg   UNK
# 4   sd-198/images/Acne_Keloidalis_Nuchae/009995HB.jpg   UNK
# ..                                                ...   ...
# 33                 sd-198/images/Xerosis/030046VB.jpg   UNK
# 34                 sd-198/images/Xerosis/030034VB.jpg   UNK
# 35                 sd-198/images/Xerosis/030053VB.jpg   UNK
# 36                 sd-198/images/Xerosis/030100HB.jpg   UNK
# 37                 sd-198/images/Xerosis/029884HB.jpg   UNK
#
# [5944 rows x 2 columns]

# %% [markdown]
# # MED-NODE Dataset
#
# I. Giotis, N. Molders, S. Land, M. Biehl, M.F. Jonkman and N. Petkov: "MED-NODE: A computer-assisted melanoma diagnosis system using non-dermoscopic images", Expert Systems with Applications, 42 (2015), 6578-6585
# http://www.cs.rug.nl/~imaging/databases/melanoma_naevi/

# %%
mednode_path = 'complete_mednode_dataset'

# %%
def get_mednode_df():
    mel = !find {mednode_path}/melanoma -type f -name '*jpg'
    nv = !find {mednode_path}/naevus -type f -name '*jpg'
    mel_df = pd.DataFrame(mel, columns =['image'])
    nv_df = pd.DataFrame(nv, columns =['image'])
    mel_df['label'] = 'MEL'
    nv_df['label'] = 'NV'
    df = pd.concat([mel_df, nv_df])
    df.rename(columns={'image': 'name'}, inplace=True)    
    return df

# %%
get_mednode_df()
# Out:
#                                               name label
# 0    complete_mednode_dataset/melanoma/2190031.jpg   MEL
# 1     complete_mednode_dataset/melanoma/136733.jpg   MEL
# 2   complete_mednode_dataset/melanoma/555361-h.jpg   MEL
# 3     complete_mednode_dataset/melanoma/252641.jpg   MEL
# 4   complete_mednode_dataset/melanoma/236042-h.jpg   MEL
# ..                                             ...   ...
# 95     complete_mednode_dataset/naevus/2192103.jpg    NV
# 96     complete_mednode_dataset/naevus/2159198.jpg    NV
# 97     complete_mednode_dataset/naevus/2191631.jpg    NV
# 98   complete_mednode_dataset/naevus/2203331-h.jpg    NV
# 99    complete_mednode_dataset/naevus/151560-h.jpg    NV
#
# [170 rows x 2 columns]

# %% [markdown]
# ## 7-point criteria evaluation Database
# J. Kawahara, S. Daneshvar, G. Argenziano and G. Hamarneh, "Seven-Point Checklist and Skin Lesion Classification Using Multitask Multimodal Neural Nets," in IEEE Journal of Biomedical and Health Informatics, vol. 23, no. 2, pp. 538-546, March 2019. https://ieeexplore.ieee.org/document/8333693
#
# Downloaded from https://derm.cs.sfu.ca/Welcome.html

# %%
derm7pt_path = 'release_v0/'

# %%
def get_derm7pt_df():
    df = pd.read_csv(derm7pt_path + 'meta/meta.csv', usecols=['derm', 'diagnosis'])
    df.rename(columns={'derm': 'name', 'diagnosis': 'label'}, inplace=True)
    
    df.loc[df['label'] == 'basal cell carcinoma', 'label'] = 'BCC'
    df.loc[df['label'] == 'lentigo', 'label'] = 'BKL'
    df.loc[df['label'] == 'seborrheic keratosis', 'label'] = 'BKL'
    df.loc[df['label'] == 'dermatofibroma', 'label'] = 'DF'
    df.loc[df['label'] == 'vascular lesion', 'label'] = 'VASC'
    # https://meshb.nlm.nih.gov/record/ui?ui=D008548
    df.loc[df['label'] == 'melanosis', 'label'] = 'BKL'
    # classified as benign melanocytic lesion
    # https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4866625/
    df.loc[df['label'] == 'reed or spitz nevus', 'label'] = 'NV'
    # Melanocytic nevus
    df.loc[df['label'] == 'blue nevus', 'label'] = 'NV'
    df.loc[df['label'] == 'clark nevus', 'label'] = 'NV'
    df.loc[df['label'] == 'combined nevus', 'label'] = 'NV'
    df.loc[df['label'] == 'congenital nevus', 'label'] = 'NV'
    df.loc[df['label'] == 'dermal nevus', 'label'] = 'NV'
    df.loc[df['label'] == 'melanoma', 'label'] = 'MEL'
    df.loc[df['label'] == 'melanoma metastasis', 'label'] = 'MEL'
    df.loc[df['label'] == 'melanoma (in situ)', 'label'] = 'MEL'
    df.loc[df['label'] == 'melanoma (less than 0.76 mm)', 'label'] = 'MEL'
    df.loc[df['label'] == 'melanoma (0.76 to 1.5 mm)', 'label'] = 'MEL'
    df.loc[df['label'] == 'melanoma (more than 1.5 mm)', 'label'] = 'MEL'
    # none of the others
    df.loc[df['label'] == 'miscellaneous', 'label'] = 'UNK'
    df.loc[df['label'] == 'recurrent nevus', 'label'] = 'UNK'
    
    df = df[['name', 'label']]
    df['name'] = df['name'].apply(lambda x: "{}images/{}".format(derm7pt_path,x))
    return df

# %%
get_derm7pt_df()
# Out:
#                                    name label
# 0      release_v0/images/NEL/Nel026.jpg   BCC
# 1      release_v0/images/NEL/Nel028.jpg   BCC
# 2      release_v0/images/NEL/Nel033.jpg   BCC
# 3      release_v0/images/NEL/Nel035.jpg   BCC
# 4      release_v0/images/NEL/Nel037.jpg   BCC
# ...                                 ...   ...
# 1006   release_v0/images/Fhl/Fhl058.jpg  VASC
# 1007   release_v0/images/Fhl/Fhl060.jpg  VASC
# 1008   release_v0/images/Fil/Fil082.jpg  VASC
# 1009  release_v0/images/New/newl016.jpg  VASC
# 1010   release_v0/images/Adl/Adl389.jpg   MEL
#
# [1011 rows x 2 columns]

# %% [markdown]
# ## PH2 Dataset
# Teresa Mendonça, Pedro M. Ferreira, Jorge Marques, Andre R. S. Marcal, Jorge Rozeira. PH² - A dermoscopic image database for research and benchmarking, 35th International Conference of the IEEE Engineering in Medicine and Biology Society, July 3-7, 2013, Osaka, Japan.
#
# https://www.fc.up.pt/addi/ph2%20database.html

# %% [markdown]
# C.Barata, M.Ruela, et al., Two Systems for the Detection of Melanomas in Dermoscopy Images using Texture and Color Features, IEEE Systems Journal, no. 99, pp. 1-15, 2013.
#
# Benchmarking results of the classification algorithms applied to the PH² database.
# <pre>
#       Extracted features            Sensibility/Specificity
# Global Method   Color features      90% / 89%
#                 Texture features    93% / 78%
# Local method    Color features      93% / 84%
#                 Texture features    88% / 76%
# </pre>

# %%
ph2_path = 'PH2Dataset/'

# %%
def get_ph2_df():
    df = pd.read_csv(ph2_path + 'PH2_dataset.txt', sep="\|\|", skipfooter=25, engine='python', usecols=[1,3])
    df.rename(columns={'   Name ': 'name', ' Clinical Diagnosis ': 'label'}, inplace=True)
    # 0: Common Nevus, 1: Atypical Nevus, 2: Melanoma.
    df.loc[df['label'] == 0, 'label'] = 'NV'
    df.loc[df['label'] == 1, 'label'] = 'NV'
    df.loc[df['label'] == 2, 'label'] = 'MEL'
    df['name'] = df['name'].apply(lambda x: "{0}PH2 Dataset images/{1}/{1}_Dermoscopic_Image/{1}.bmp".format(ph2_path,x.strip()))
    return df

# %%
get_ph2_df()
# Out:
#                                                   name label
# 0    PH2Dataset/PH2 Dataset images/IMD003/IMD003_De...    NV
# 1    PH2Dataset/PH2 Dataset images/IMD009/IMD009_De...    NV
# 2    PH2Dataset/PH2 Dataset images/IMD016/IMD016_De...    NV
# 3    PH2Dataset/PH2 Dataset images/IMD022/IMD022_De...    NV
# 4    PH2Dataset/PH2 Dataset images/IMD024/IMD024_De...    NV
# ..                                                 ...   ...
# 195  PH2Dataset/PH2 Dataset images/IMD424/IMD424_De...   MEL
# 196  PH2Dataset/PH2 Dataset images/IMD425/IMD425_De...   MEL
# 197  PH2Dataset/PH2 Dataset images/IMD426/IMD426_De...   MEL
# 198  PH2Dataset/PH2 Dataset images/IMD429/IMD429_De...   MEL
# 199  PH2Dataset/PH2 Dataset images/IMD435/IMD435_De...   MEL
#
# [200 rows x 2 columns]

# %% [markdown]
# ## Light Field Image Dataset of Skin Lesions
# S. M. M. de Faria et al., "Light Field Image Dataset of Skin Lesions," 2019 41st Annual International Conference of the IEEE Engineering in Medicine and Biology Society (EMBC), Berlin, Germany, 2019, pp. 3905-3908. DOI: 10.1109/EMBC.2019.8856578
#
# https://www.it.pt/AutomaticPage?id=3459

# %%
skinl2_path = 'SKINL2_v2/Dermatoscopic'

# %%
# !ls {skinl2_path}
# Out:
# 'Basal-cell Carcinoma'	 Melanoma   Others
#  Hemangioma		 Nevus	   'Seborrheic Keratosis'

# %%
def get_skinl2_df():
    bcc = !find "{skinl2_path}/Basal-cell Carcinoma" -type f -name "*.png"
    mel = !find {skinl2_path}/Melanoma -type f -name "*.png"
    bkl = !find "{skinl2_path}/Seborrheic Keratosis" -type f -name "*.png"
    nv = !find {skinl2_path}/Nevus -type f -name "*.png"
    bcc_df = pd.DataFrame(bcc)
    mel_df = pd.DataFrame(mel)
    bkl_df = pd.DataFrame(bkl)
    nv_df = pd.DataFrame(nv)
    bcc_df['label'] = 'BCC'
    mel_df['label'] = 'MEL'
    bkl_df['label'] = 'BKL'
    nv_df['label'] = 'DF'
    df = pd.concat([bcc_df, mel_df, bkl_df, nv_df])
    df.columns = ['name', 'label']
    return df

# %%
get_skinl2_df()
# Out:
#                                                  name label
# 0   SKINL2_v2/Dermatoscopic/Basal-cell Carcinoma/0...   BCC
# 1   SKINL2_v2/Dermatoscopic/Basal-cell Carcinoma/0...   BCC
# 2   SKINL2_v2/Dermatoscopic/Basal-cell Carcinoma/0...   BCC
# 3   SKINL2_v2/Dermatoscopic/Basal-cell Carcinoma/0...   BCC
# 4   SKINL2_v2/Dermatoscopic/Basal-cell Carcinoma/0...   BCC
# ..                                                ...   ...
# 30  SKINL2_v2/Dermatoscopic/Nevus/0030_Dermatoscop...    DF
# 31  SKINL2_v2/Dermatoscopic/Nevus/0018_2_Dermatosc...    DF
# 32  SKINL2_v2/Dermatoscopic/Nevus/0038_Dermatoscop...    DF
# 33  SKINL2_v2/Dermatoscopic/Nevus/0012_Dermatoscop...    DF
# 34  SKINL2_v2/Dermatoscopic/Nevus/0021_Dermatoscop...    DF
#
# [92 rows x 2 columns]

# %% [markdown]
# # Prepare training dataset

# %%
def get_external_df():
    return pd.concat([get_sd198_df(), get_ph2_df(), get_derm7pt_df(), get_skinl2_df(), get_mednode_df()], sort=False)

# %%
data_df = pd.concat([get_external_df(), get_isic_df()], sort=False) if use_external_data else get_isic_df()

# %%
ax = sns.countplot(x="label", data=data_df, order=['NV', 'MEL', 'BCC', 'BKL', 'AK', 'SCC', 'DF', 'VASC', 'UNK'])

# %%
data_df
# Out:
#                                                     name label
# 0      sd-198/images/Acne_Keloidalis_Nuchae/010069HB.jpg   UNK
# 1      sd-198/images/Acne_Keloidalis_Nuchae/042338HB.jpg   UNK
# 2      sd-198/images/Acne_Keloidalis_Nuchae/010018HB.jpg   UNK
# 3      sd-198/images/Acne_Keloidalis_Nuchae/009931HB.jpg   UNK
# 4      sd-198/images/Acne_Keloidalis_Nuchae/009995HB.jpg   UNK
# ...                                                  ...   ...
# 25326  isic_preproc/ISIC_2019_Training_Input/ISIC_007...   BCC
# 25327  isic_preproc/ISIC_2019_Training_Input/ISIC_007...   BKL
# 25328  isic_preproc/ISIC_2019_Training_Input/ISIC_007...   MEL
# 25329  isic_preproc/ISIC_2019_Training_Input/ISIC_007...    NV
# 25330  isic_preproc/ISIC_2019_Training_Input/ISIC_007...   BKL
#
# [32748 rows x 2 columns]

# %% [markdown]
# # Data Augmentation

# %%
xtra_tfms = (cutout(n_holes=(1,1), length=(16,16), p=.5))
tfms = get_transforms(max_rotate=45, 
                      p_affine=0.5, 
                      p_lighting=0.5,
                      do_flip=True, 
                      flip_vert=True, 
                      max_zoom=1.05, 
                      max_warp=None, 
                      max_lighting=0.2,
                      xtra_tfms=xtra_tfms)

# %% [markdown]
# # Load training and test datasets

# %%
data = ImageDataBunch.from_df(path = './', df=data_df, ds_tfms=tfms, size=299,
                              resize_method=ResizeMethod.PAD, bs=batch_size,
                              valid_pct=0.1)

# %%
test = ImageList.from_df(df=get_isic_test_df(), path = './', 
                         folder='ISIC_2019_Test_Input', 
                         suffix='.jpg')

# %%
data.add_test(test)

# %%
data.show_batch(rows=3, figsize=(6,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['AK', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'SCC', 'UNK', 'VASC']
# (9, 9)

# %% [markdown]
# # Load pretrained model

# %% [markdown]
# Loading model pretrained on ImageNet dataset.

# %%
# cnn_learner() expects a callable function
def get_cadene_model(pretrained=True, model_name=model_name):
    if pretrained:
        arch = pretrainedmodels.__dict__[model_name](num_classes=1000, pretrained='imagenet')
    else:
        arch = pretrainedmodels.__dict__[model_name](num_classes=1000, pretrained=None)
    return arch

# %%
learn = cnn_learner(data, get_cadene_model, metrics=accuracy)

# %% [markdown]
# ## Configure weighted cross entropy loss

# %%
data_df['label'].value_counts()
# Out:
# NV      13704
# UNK      5958
# MEL      4904
# BCC      3378
# BKL      2733
# AK        867
# SCC       628
# DF        294
# VASC      282
# Name: label, dtype: int64

# %%
total_images = data_df.shape[0]
total_images
# Out:
# 32748

# %%
weights_loss = []

for c in data.classes:
    samples = data_df['label'].value_counts()[c]
    weights_loss.append(1 / (samples / total_images))

# %%
data.classes
# Out:
# ['AK', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'SCC', 'UNK', 'VASC']

# %%
normalized_weights = [x / sum(weights_loss) for x in weights_loss]

# %%
normalized_weights
# Out:
# [0.10679773153210781,
#  0.0274107854465179,
#  0.033879851166607196,
#  0.3149443307426445,
#  0.018881246582042713,
#  0.006756686605249378,
#  0.14744209114384949,
#  0.01554105962375587,
#  0.32834621715722506]

# %%
pd.DataFrame(normalized_weights, data.classes).plot(kind='bar', legend=None)

# %% [markdown]
# Maybe we should give malignant classes like MEL, BCC higher penalty.

# %%
if use_weighted_loss:
    from torch import nn

    class_weights=torch.FloatTensor(normalized_weights).cuda()
    learn.crit = nn.CrossEntropyLoss(weight=class_weights)

# %% [markdown]
# # Transfer learning

# %% [markdown]
# Fit model using <a href="https://docs.fast.ai/callbacks.one_cycle.html">one cycle</a> policy (https://arxiv.org/pdf/1803.09820.pdf).

# %%
learn.fit_one_cycle(32)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.052792</td>
#       <td>0.774298</td>
#       <td>0.734575</td>
#       <td>17:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.865527</td>
#       <td>0.710368</td>
#       <td>0.748626</td>
#       <td>16:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.860744</td>
#       <td>0.678524</td>
#       <td>0.746487</td>
#       <td>16:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.804907</td>
#       <td>0.656460</td>
#       <td>0.766646</td>
#       <td>16:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.741977</td>
#       <td>0.634877</td>
#       <td>0.773671</td>
#       <td>16:56</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.739901</td>
#       <td>0.608625</td>
#       <td>0.778558</td>
#       <td>16:58</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.731936</td>
#       <td>0.585407</td>
#       <td>0.785889</td>
#       <td>16:59</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.687518</td>
#       <td>0.581212</td>
#       <td>0.786805</td>
#       <td>16:55</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.636198</td>
#       <td>0.556157</td>
#       <td>0.798717</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.652973</td>
#       <td>0.537542</td>
#       <td>0.804520</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.600904</td>
#       <td>0.525128</td>
#       <td>0.812462</td>
#       <td>16:52</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.603685</td>
#       <td>0.511558</td>
#       <td>0.816127</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.579346</td>
#       <td>0.517622</td>
#       <td>0.810935</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.586652</td>
#       <td>0.497759</td>
#       <td>0.821319</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.576596</td>
#       <td>0.485494</td>
#       <td>0.824068</td>
#       <td>16:52</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.546562</td>
#       <td>0.476993</td>
#       <td>0.823458</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.525092</td>
#       <td>0.464193</td>
#       <td>0.831093</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.510244</td>
#       <td>0.462887</td>
#       <td>0.830788</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.527569</td>
#       <td>0.450022</td>
#       <td>0.833232</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.504193</td>
#       <td>0.450830</td>
#       <td>0.837202</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.455845</td>
#       <td>0.443615</td>
#       <td>0.843311</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.468032</td>
#       <td>0.438583</td>
#       <td>0.843311</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.469132</td>
#       <td>0.441630</td>
#       <td>0.840257</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.425070</td>
#       <td>0.429876</td>
#       <td>0.842395</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.427708</td>
#       <td>0.425617</td>
#       <td>0.847587</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.460781</td>
#       <td>0.428762</td>
#       <td>0.850031</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.431253</td>
#       <td>0.422881</td>
#       <td>0.848503</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.446966</td>
#       <td>0.432126</td>
#       <td>0.846976</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.392724</td>
#       <td>0.415575</td>
#       <td>0.852779</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.416223</td>
#       <td>0.421154</td>
#       <td>0.848503</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.376791</td>
#       <td>0.417750</td>
#       <td>0.850947</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.425621</td>
#       <td>0.425516</td>
#       <td>0.849420</td>
#       <td>16:53</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(filename + '_stage_1')

# %% [markdown]
# ## Results after transfer learning

# %% [markdown]
# Look at most incorrect predictions and plot confusion matrix.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(16, figsize=(11,11))

# %%
interp.plot_confusion_matrix(figsize=(6,6), dpi=60)

# %%
interp.plot_confusion_matrix(figsize=(6,6), dpi=60, normalize=True)

# %%
interp.most_confused(min_val=20)
# Out:
# [('MEL', 'NV', 153),
#  ('BKL', 'NV', 53),
#  ('NV', 'MEL', 41),
#  ('BCC', 'NV', 29),
#  ('BKL', 'MEL', 21),
#  ('AK', 'BCC', 20)]

# %% [markdown]
# # Unfreezing, fine-tuning, differential learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='76' class='' max='1842', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.13% [76/1842 01:01<23:56 1.4643]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.458700</td>
#       <td>0.758246</td>
#       <td>0.845754</td>
#       <td>23:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.612620</td>
#       <td>0.902218</td>
#       <td>0.808186</td>
#       <td>23:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.580555</td>
#       <td>0.816373</td>
#       <td>0.820098</td>
#       <td>23:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.502418</td>
#       <td>1.178728</td>
#       <td>0.832621</td>
#       <td>23:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.450858</td>
#       <td>0.438234</td>
#       <td>0.851558</td>
#       <td>23:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.402446</td>
#       <td>0.936693</td>
#       <td>0.851863</td>
#       <td>23:26</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.349474</td>
#       <td>0.558504</td>
#       <td>0.869578</td>
#       <td>23:46</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.259976</td>
#       <td>0.815298</td>
#       <td>0.878742</td>
#       <td>23:45</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.236008</td>
#       <td>0.595622</td>
#       <td>0.883629</td>
#       <td>23:33</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.211288</td>
#       <td>0.589447</td>
#       <td>0.884850</td>
#       <td>24:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(filename + '_stage_2')

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='59' class='' max='1842', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       3.20% [59/1842 00:46<23:32 0.3602]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=(1e-6,1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.183595</td>
#       <td>0.397855</td>
#       <td>0.884545</td>
#       <td>23:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.194487</td>
#       <td>0.437889</td>
#       <td>0.885156</td>
#       <td>23:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.200941</td>
#       <td>0.585356</td>
#       <td>0.887294</td>
#       <td>23:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.200499</td>
#       <td>0.949889</td>
#       <td>0.883018</td>
#       <td>23:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.181279</td>
#       <td>0.586585</td>
#       <td>0.885767</td>
#       <td>23:28</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.189689</td>
#       <td>0.568758</td>
#       <td>0.890348</td>
#       <td>23:28</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.219293</td>
#       <td>0.583875</td>
#       <td>0.886683</td>
#       <td>23:28</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.185314</td>
#       <td>0.709219</td>
#       <td>0.886378</td>
#       <td>23:28</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.171086</td>
#       <td>0.651023</td>
#       <td>0.886988</td>
#       <td>23:44</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.184779</td>
#       <td>0.522457</td>
#       <td>0.890043</td>
#       <td>23:30</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(filename + '_stage_3')

# %%
learn.load(filename + '_stage_3')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (29474 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# UNK,UNK,UNK,UNK,UNK
# Path: .;
#
# Valid: LabelList (3274 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# NV,MEL,BCC,AK,MEL
# Path: .;
#
# Test: LabelList (8238 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: EmptyLabelList
# ,,,,
# Path: ., model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     )
#     (1): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (2): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (3): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (3): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (3): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (4): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (5): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (6): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (7): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (8): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (9): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (10): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (11): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (12): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (13): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (14): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (15): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (16): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (17): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (18): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (19): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (20): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (21): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (22): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (4): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=4096, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=9, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7febabaf4e60>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (4): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU(inplace=True)
#   (11): AdaptiveAvgPool2d(output_size=1)
#   (12): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (15): Sigmoid()
#   (16): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (19): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU(inplace=True)
#   (25): AdaptiveAvgPool2d(output_size=1)
#   (26): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (29): Sigmoid()
#   (30): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (31): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (33): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (34): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (35): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): ReLU(inplace=True)
#   (37): AdaptiveAvgPool2d(output_size=1)
#   (38): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   (39): ReLU(inplace=True)
#   (40): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (41): Sigmoid()
#   (42): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (43): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#   (45): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (48): ReLU(inplace=True)
#   (49): AdaptiveAvgPool2d(output_size=1)
#   (50): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (51): ReLU(inplace=True)
#   (52): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (53): Sigmoid()
#   (54): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (55): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (57): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (58): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (59): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (60): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (61): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (62): ReLU(inplace=True)
#   (63): AdaptiveAvgPool2d(output_size=1)
#   (64): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (65): ReLU(inplace=True)
#   (66): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (67): Sigmoid()
#   (68): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (69): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (70): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (71): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (72): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (73): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (74): ReLU(inplace=True)
#   (75): AdaptiveAvgPool2d(output_size=1)
#   (76): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (77): ReLU(inplace=True)
#   (78): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (79): Sigmoid()
#   (80): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (81): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (82): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (83): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (84): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (85): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (86): ReLU(inplace=True)
#   (87): AdaptiveAvgPool2d(output_size=1)
#   (88): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (89): ReLU(inplace=True)
#   (90): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (91): Sigmoid()
#   (92): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (93): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (94): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#   (95): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (96): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (97): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (98): ReLU(inplace=True)
#   (99): AdaptiveAvgPool2d(output_size=1)
#   (100): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (101): ReLU(inplace=True)
#   (102): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (103): Sigmoid()
#   (104): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (105): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (106): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (107): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (108): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (109): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (110): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (111): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (112): ReLU(inplace=True)
#   (113): AdaptiveAvgPool2d(output_size=1)
#   (114): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (115): ReLU(inplace=True)
#   (116): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (117): Sigmoid()
#   (118): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (119): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (120): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (121): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (122): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (123): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (124): ReLU(inplace=True)
#   (125): AdaptiveAvgPool2d(output_size=1)
#   (126): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (127): ReLU(inplace=True)
#   (128): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (129): Sigmoid()
#   (130): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (131): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (132): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (133): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (134): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (135): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (136): ReLU(inplace=True)
#   (137): AdaptiveAvgPool2d(output_size=1)
#   (138): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (139): ReLU(inplace=True)
#   (140): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (141): Sigmoid()
#   (142): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (143): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (144): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (145): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (146): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (147): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (148): ReLU(inplace=True)
#   (149): AdaptiveAvgPool2d(output_size=1)
#   (150): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (151): ReLU(inplace=True)
#   (152): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (153): Sigmoid()
#   (154): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (155): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (156): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (157): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (158): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (159): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (160): ReLU(inplace=True)
#   (161): AdaptiveAvgPool2d(output_size=1)
#   (162): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (163): ReLU(inplace=True)
#   (164): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (165): Sigmoid()
#   (166): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (167): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (168): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (169): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (170): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (171): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (172): ReLU(inplace=True)
#   (173): AdaptiveAvgPool2d(output_size=1)
#   (174): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (175): ReLU(inplace=True)
#   (176): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (177): Sigmoid()
#   (178): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (179): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (180): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (181): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (182): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (183): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (184): ReLU(inplace=True)
#   (185): AdaptiveAvgPool2d(output_size=1)
#   (186): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (187): ReLU(inplace=True)
#   (188): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (189): Sigmoid()
#   (190): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (191): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (192): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (193): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (194): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (195): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (196): ReLU(inplace=True)
#   (197): AdaptiveAvgPool2d(output_size=1)
#   (198): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (199): ReLU(inplace=True)
#   (200): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (201): Sigmoid()
#   (202): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (203): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (204): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (205): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (206): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (207): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (208): ReLU(inplace=True)
#   (209): AdaptiveAvgPool2d(output_size=1)
#   (210): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (211): ReLU(inplace=True)
#   (212): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (213): Sigmoid()
#   (214): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (215): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (216): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (217): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (218): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (219): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (220): ReLU(inplace=True)
#   (221): AdaptiveAvgPool2d(output_size=1)
#   (222): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (223): ReLU(inplace=True)
#   (224): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (225): Sigmoid()
#   (226): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (227): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (228): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (229): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (230): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (231): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (232): ReLU(inplace=True)
#   (233): AdaptiveAvgPool2d(output_size=1)
#   (234): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (235): ReLU(inplace=True)
#   (236): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (237): Sigmoid()
#   (238): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (239): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (240): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (241): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (242): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (243): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (244): ReLU(inplace=True)
#   (245): AdaptiveAvgPool2d(output_size=1)
#   (246): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (247): ReLU(inplace=True)
#   (248): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (249): Sigmoid()
#   (250): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (251): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (252): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (253): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (254): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (255): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (256): ReLU(inplace=True)
#   (257): AdaptiveAvgPool2d(output_size=1)
#   (258): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (259): ReLU(inplace=True)
#   (260): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (261): Sigmoid()
#   (262): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (263): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (264): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (265): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (266): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (267): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (268): ReLU(inplace=True)
#   (269): AdaptiveAvgPool2d(output_size=1)
#   (270): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (271): ReLU(inplace=True)
#   (272): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (273): Sigmoid()
#   (274): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (275): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (276): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (277): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (278): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (279): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (280): ReLU(inplace=True)
#   (281): AdaptiveAvgPool2d(output_size=1)
#   (282): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (283): ReLU(inplace=True)
#   (284): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (285): Sigmoid()
#   (286): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (287): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (288): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (289): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (290): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (291): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (292): ReLU(inplace=True)
#   (293): AdaptiveAvgPool2d(output_size=1)
#   (294): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (295): ReLU(inplace=True)
#   (296): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (297): Sigmoid()
#   (298): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (299): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (300): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (301): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (302): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (303): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (304): ReLU(inplace=True)
#   (305): AdaptiveAvgPool2d(output_size=1)
#   (306): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (307): ReLU(inplace=True)
#   (308): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (309): Sigmoid()
#   (310): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (311): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (312): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (313): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (314): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (315): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (316): ReLU(inplace=True)
#   (317): AdaptiveAvgPool2d(output_size=1)
#   (318): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (319): ReLU(inplace=True)
#   (320): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (321): Sigmoid()
#   (322): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (323): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (324): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (325): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (326): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (327): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (328): ReLU(inplace=True)
#   (329): AdaptiveAvgPool2d(output_size=1)
#   (330): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (331): ReLU(inplace=True)
#   (332): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (333): Sigmoid()
#   (334): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (335): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (336): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (337): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (338): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (339): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (340): ReLU(inplace=True)
#   (341): AdaptiveAvgPool2d(output_size=1)
#   (342): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (343): ReLU(inplace=True)
#   (344): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (345): Sigmoid()
#   (346): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (347): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (348): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (349): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (350): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (351): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (352): ReLU(inplace=True)
#   (353): AdaptiveAvgPool2d(output_size=1)
#   (354): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (355): ReLU(inplace=True)
#   (356): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (357): Sigmoid()
#   (358): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (359): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (360): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (361): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (362): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (363): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (364): ReLU(inplace=True)
#   (365): AdaptiveAvgPool2d(output_size=1)
#   (366): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (367): ReLU(inplace=True)
#   (368): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (369): Sigmoid()
#   (370): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (371): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (372): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#   (373): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (374): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (375): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (376): ReLU(inplace=True)
#   (377): AdaptiveAvgPool2d(output_size=1)
#   (378): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (379): ReLU(inplace=True)
#   (380): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (381): Sigmoid()
#   (382): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (383): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (384): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (385): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (386): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (387): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (388): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (389): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (390): ReLU(inplace=True)
#   (391): AdaptiveAvgPool2d(output_size=1)
#   (392): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (393): ReLU(inplace=True)
#   (394): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (395): Sigmoid()
#   (396): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (397): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (398): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (399): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (400): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (401): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (402): ReLU(inplace=True)
#   (403): AdaptiveAvgPool2d(output_size=1)
#   (404): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (405): ReLU(inplace=True)
#   (406): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (407): Sigmoid()
# ), Sequential(
#   (0): AdaptiveAvgPool2d(output_size=1)
#   (1): AdaptiveMaxPool2d(output_size=1)
#   (2): Flatten()
#   (3): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Dropout(p=0.25, inplace=False)
#   (5): Linear(in_features=4096, out_features=512, bias=True)
#   (6): ReLU(inplace=True)
#   (7): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Dropout(p=0.5, inplace=False)
#   (9): Linear(in_features=512, out_features=9, bias=True)
# )], add_time=True, silent=False)

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(3, max_lr=1e-6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.220523</td>
#       <td>0.684127</td>
#       <td>0.949603</td>
#       <td>23:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.223435</td>
#       <td>0.287605</td>
#       <td>0.956323</td>
#       <td>23:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.220657</td>
#       <td>0.262610</td>
#       <td>0.957239</td>
#       <td>23:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(filename + '_stage_4')

# %% [markdown]
# # Evaluate model

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %% [markdown]
# Show most incorrect predictions. The title of each image shows: prediction, actual, loss, probability of actual class. Grad-CAM heatmaps (http://openaccess.thecvf.com/content_ICCV_2017/papers/Selvaraju_Grad-CAM_Visual_Explanations_ICCV_2017_paper.pdf) are overlaid on each image.

# %%
interp.plot_top_losses(16, figsize=(11,11), heatmap=True)

# %%
interp.plot_top_losses(16, figsize=(11,11))

# %%
interp.plot_confusion_matrix(figsize=(6,6), dpi=60)

# %%
interp.plot_confusion_matrix(figsize=(6,6), dpi=60, normalize=True)

# %% [markdown]
# ## Predict on test dataset
# Predict on test dataset and prepare CSV containing results.

# %%
#learn.load(filename + '_stage_2')

# %% [markdown]
# Compute predictions using test time augmentation.

# %%
preds, avg_preds, y = learn.TTA(ds_type=DatasetType.Test, beta=None)

# %%
result_df = pd.DataFrame(columns=data.classes, data=avg_preds.tolist())

# %%
result_df['image'] = get_isic_test_df()

# %%
result_df_header = ['image','MEL','NV','BCC','AK','BKL','DF','VASC','SCC','UNK']

# %% [markdown]
# We assume no out of distribution images here.

# %%
#result_df['UNK'] = 0.0

# %%
result_df = result_df[result_df_header]

# %%
result_df
# Out:
#              image       MEL        NV           BCC            AK       BKL  \
# 0     ISIC_0034321  0.061823  0.892505  4.517513e-02  7.262105e-06  0.000246
# 1     ISIC_0034322  0.001141  0.998547  1.663161e-05  2.345887e-06  0.000270
# 2     ISIC_0034323  0.000454  0.002006  9.825711e-01  7.683291e-03  0.000944
# 3     ISIC_0034324  0.004994  0.994975  2.135887e-08  3.994307e-09  0.000008
# 4     ISIC_0034325  0.000101  0.999815  4.501134e-08  6.815670e-09  0.000084
# ...            ...       ...       ...           ...           ...       ...
# 8233  ISIC_0073236  0.001020  0.016815  9.351640e-01  6.078864e-04  0.046211
# 8234  ISIC_0073243  0.376878  0.001651  6.111734e-01  6.373499e-03  0.000769
# 8235  ISIC_0073250  0.003817  0.965798  2.615686e-02  1.202927e-03  0.002808
# 8236  ISIC_0073252  0.012821  0.530123  2.392289e-01  3.485614e-04  0.214486
# 8237  ISIC_0073253  0.069176  0.001088  1.396607e-01  1.569377e-01  0.508235
#
#                 DF          VASC           SCC           UNK
# 0     2.227752e-04  1.768208e-05  2.999507e-06  5.887467e-09
# 1     2.134988e-05  9.468922e-08  4.974242e-07  7.677015e-07
# 2     3.860586e-04  9.120834e-07  5.953527e-03  2.015799e-07
# 3     7.915564e-09  9.687434e-06  8.718997e-09  1.364630e-05
# 4     9.784960e-09  4.596305e-09  3.444829e-10  8.416011e-10
# ...            ...           ...           ...           ...
# 8233  3.428038e-06  1.589094e-07  1.758491e-04  3.629851e-06
# 8234  3.572654e-05  5.441258e-04  2.573988e-03  1.673724e-06
# 8235  1.199800e-04  7.462296e-05  1.307457e-05  1.005862e-05
# 8236  1.232331e-05  2.656301e-03  3.231416e-04  2.453108e-07
# 8237  2.159190e-02  1.990323e-04  1.023639e-01  7.481384e-04
#
# [8238 rows x 10 columns]

# %% [markdown]
# ### Thresholding

# %% [markdown]
# $$
# \begin{equation*}p(c|x)= \frac{p(x|c)p(c)}{p(x)}\end{equation*}
# $$
#
# Bayes rule. The model predicts the probability of a class c given x.

# %% [markdown]
#  By dividing by $ {p(c) $ we get $ p(x|c) $ .

# %%
data.classes
# Out:
# ['AK', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'SCC', 'UNK', 'VASC']

# %%
weights_loss
# Out:
# [37.77162629757785,
#  9.694493783303729,
#  11.98243688254665,
#  111.38775510204083,
#  6.677814029363784,
#  2.3896672504378285,
#  52.146496815286625,
#  5.496475327291037,
#  116.12765957446808]

# %%
result_thresh_df = result_df.copy()

# %%
result_thresh_df.loc[:, data.classes] *= weights_loss

# %% [markdown]
# Normalize results.

# %%
result_thresh_df.loc[:, data.classes] = result_thresh_df.loc[:, data.classes].div(result_thresh_df.sum(axis=1), axis=0)

# %%
# https://stackoverflow.com/a/36328021
def csv_download_link(df, csv_file_name):
    """Display a download link to load a data frame as csv from within a Jupyter notebook"""
    df.to_csv(csv_file_name, index=False)
    from IPython.display import FileLink
    display(FileLink(csv_file_name))

# %%
csv_download_link(result_df, 'result_' + filename + '.csv')
csv_download_link(result_thresh_df, 'result_thresh_' + filename + '.csv')
# Out:
# /home/js/data/isic/result_se_resnext101_32x4d_preproc_ext_data_thres.csv
# /home/js/data/isic/result_thresh_se_resnext101_32x4d_preproc_ext_data_thres.csv

# %% [markdown]
# Submit CSV at https://challenge.isic-archive.com/task/55
