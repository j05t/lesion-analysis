# %%
import pandas as pd

# %%
files = ['result_thresh_se_resnext101_32x4d_preproc_ext_data_thres.csv',  # 0.582
        'result_thresh_se_resnext101_32x4d_preproc_ext_data_thres_2.csv', # 0.578
        'result_thresh_se_resnext101_32x4d_preproc_ext_data_thres_3.csv', # 0.572
        'result_thresh_inceptionresnetv2_preproc_ext_data_thres.csv']     # 0.569

# %%
averaged = pd.read_csv(files[0])
count = 1

for f in files[1:]:
    averaged.iloc[:,range(1,10)] += pd.read_csv(f).iloc[:,range(1,10)]
    count += 1

averaged.iloc[:,range(1,10)] /= count

# %%
averaged
# Out:
#              image       MEL        NV       BCC        AK       BKL  \
# 0     ISIC_0034321  0.104653  0.706272  0.144130  0.001397  0.011623
# 1     ISIC_0034322  0.004524  0.990907  0.000067  0.000068  0.001995
# 2     ISIC_0034323  0.000707  0.000325  0.770878  0.064696  0.002371
# 3     ISIC_0034324  0.010175  0.985083  0.000002  0.000001  0.001070
# 4     ISIC_0034325  0.003524  0.995392  0.000243  0.000046  0.000527
# ...            ...       ...       ...       ...       ...       ...
# 8233  ISIC_0073236  0.027307  0.001571  0.919425  0.012714  0.023606
# 8234  ISIC_0073243  0.183060  0.002685  0.744346  0.015394  0.001353
# 8235  ISIC_0073250  0.032707  0.736588  0.152873  0.026373  0.014809
# 8236  ISIC_0073252  0.014321  0.201733  0.207847  0.010055  0.173514
# 8237  ISIC_0073253  0.017268  0.000410  0.066870  0.132343  0.284028
#
#             DF      VASC       SCC           UNK
# 0     0.016675  0.012032  0.003215  1.984322e-06
# 1     0.002279  0.000066  0.000091  3.877184e-06
# 2     0.004495  0.000153  0.156375  3.395058e-07
# 3     0.000010  0.003594  0.000001  6.261451e-05
# 4     0.000075  0.000166  0.000028  3.593949e-08
# ...        ...       ...       ...           ...
# 8233  0.000424  0.000318  0.014635  5.725384e-07
# 8234  0.000272  0.046900  0.005988  2.887588e-06
# 8235  0.012367  0.022308  0.001956  1.845098e-05
# 8236  0.014027  0.374577  0.003920  6.297288e-06
# 8237  0.148383  0.010153  0.340436  1.093688e-04
#
# [8238 rows x 10 columns]

# %%
averaged.to_csv('result_ensemble_averaged.csv', index=False)

# %% [markdown]
# Submit at https://challenge.isic-archive.com/task/55
